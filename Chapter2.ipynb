# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exercises: Applied

# %% [markdown]
# ## Question 8).

# %% [markdown]
# This exercise relates to the College data set, which can be found in
# the file College.csv. It contains a number of variables for 777 different
# universities and colleges in the US. The variables are
#
# • Private : Public/private indicator
#
# • Apps : Number of applications received
#
# • Accept : Number of applicants accepted
#
# • Enroll : Number of new students enrolled
#
# • Top10perc : New students from top 10 % of high school class
#
# • Top25perc : New students from top 25 % of high school class
#
# • F.Undergrad : Number of full-time undergraduates
#
# • P.Undergrad : Number of part-time undergraduates
#
# • Outstate : Out-of-state tuition
#
# • Room.Board : Room and board costs
#
# • Books : Estimated book costs
#
# • Personal : Estimated personal spending
#
# • PhD : Percent of faculty with Ph.D.’s
#
# • Terminal : Percent of faculty with terminal degree
#
# • S.F.Ratio : Student/faculty ratio
#
# • perc.alumni : Percent of alumni who donate
#
# • Expend : Instructional expenditure per student
#
# • Grad.Rate : Graduation rate

# %% [markdown]
# ### 8 (a)
#
# Use the read.csv() function to read the data into R. Call theloaded data college. Make sure that you have the directory set to the correct location for the data.

# %%
df_college = pd.read_csv('datasets/College.csv')
df_college.head(2)
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56

# %% [markdown]
# ### 8 (b)
#
# Look at the data using the fix() function. You should notice that the first column is just the name of each university. We don’t really want R to treat this as data. However, it may be handy to have these names for later.

# %%
df_college.drop(columns='Unnamed: 0', inplace=True)

# %%
df_college.head(2)
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56

# %% [markdown]
# ### 8 (c) i).
#  Use the summary() function to produce a numerical summary
# of the variables in the data set.

# %%
df_college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ### 8 (c) ii).
#
# Use the pairs() function to produce a scatterplot matrix of
# the first ten columns or variables of the data. Recall that
# you can reference the first ten columns of a matrix A using
# A[,1:10].

# %%
sns.pairplot(df_college[df_college.columns.tolist()[:10]])

# %% [markdown]
# ### 8 (c) iii).
# Use the plot() function to produce side-by-side boxplots of
# Outstate versus Private.

# %%
sns.boxplot(x='Private', y='Outstate', data=df_college)

# %% [markdown]
# ### 8 (c) iv).
#
# Create a new qualitative variable, called Elite, by binning
# the Top10perc variable. We are going to divide universities
# into two groups based on whether or not the proportion
# of students coming from the top 10 % of their high school
# classes exceeds 50 %.
#
# Use the summary() function to see how many elite universities there are. Now use the plot() function to produce
# side-by-side boxplots of Outstate versus Elite.

# %%
df_college['Elite'] = df_college['Top10perc'].apply(lambda x: 'Yes' if x>50 else 'No')

# %%
df_college.Elite.value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
sns.boxenplot(x='Outstate', y='Elite', data=df_college)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ### 8 (c) v).
#
# Use the hist() function to produce some histograms with
# differing numbers of bins for a few of the quantitative variables. You may find the command par(mfrow=c(2,2)) useful:
# it will divide the print window into four regions so that four
# plots can be made simultaneously. Modifying the arguments
# to this function will divide the screen in other ways.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12,6))
sns.distplot(df_college.Enroll, ax=ax1)
sns.distplot(df_college.Enroll, bins=5, ax=ax2)
sns.distplot(df_college.Enroll, bins=2, ax=ax3)

# %% [markdown]
# ### 8 (c) vi).
# Continue exploring the data, and provide a brief summary
# of what you discover.

# %%
df_college.groupby('Elite').mean()[['Expend', 'Grad.Rate']]
# Out:
#              Expend  Grad.Rate
# Elite
# No      8684.367668  63.463519
# Yes    18404.871795  83.384615

# %% [markdown]
# * We observe high grad rates as well as more than double expenses on average for Elite colleges.

# %% [markdown]
# ## Question 9).
# This exercise involves the Auto data set studied in the lab. Make sure
# that the missing values have been removed from the data.

# %%
df_auto = pd.read_csv('datasets/Auto.data', delim_whitespace=True)
df_auto.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0    70
# 1  15.0          8         350.0      165.0  3693.0          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %% [markdown]
# ### 9 (a).
# Which of the predictors are quantitative, and which are qualitative?

# %% [markdown]
# * Quantitative: mpg, cylinders, displacement, horsepower, weight, acceleration
# * Qualitative: year, origin, name

# %% [markdown]
# ### 9 (b).
#
# What is the range of each quantitative predictor? You can answer this using the range() function.

# %%
df_auto[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration']].describe().T[['min', 'max']]
# Out:
#                  min     max
# mpg              9.0    46.6
# cylinders        3.0     8.0
# displacement    68.0   455.0
# weight        1613.0  5140.0
# acceleration     8.0    24.8

# %% [markdown]
# ### 9 (c).
#
# What is the mean and standard deviation of each quantitative
# predictor?

# %%
df_auto[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration']].describe().T[['mean', 'std']]
# Out:
#                      mean         std
# mpg             23.515869    7.825804
# cylinders        5.458438    1.701577
# displacement   193.532746  104.379583
# weight        2970.261965  847.904119
# acceleration    15.555668    2.749995

# %% [markdown]
# ### 9 (d).
#
# Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %%
df_auto_temp = pd.concat([df_auto.iloc[:10], df_auto.iloc[85:]])

# %%
df_auto.shape, df_auto_temp.shape
# Out:
# ((397, 9), (322, 9))

# %%
df_auto_temp[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration']].describe().T[['min', 'max']]
# Out:
#                  min     max
# mpg             11.0    46.6
# cylinders        3.0     8.0
# displacement    68.0   455.0
# weight        1649.0  4997.0
# acceleration     8.5    24.8

# %% [markdown]
# ### 9 (e).
# Using the full data set, investigate the predictors graphically,
# using scatterplots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment
# on your findings.

# %%
sns.regplot(x='cylinders', y='mpg', data=df_auto)

# %%
sns.regplot(x='weight', y='acceleration', data=df_auto)

# %% [markdown]
# * Weight and acceleration are inversely proportional, high cylinder vehicles have lower mpg.

# %% [markdown]
# ### 9 (f).
#
# Suppose that we wish to predict gas mileage (mpg) on the basis
# of the other variables. Do your plots suggest that any of the
# other variables might be useful in predicting mpg? Justify your
# answer.

# %%
sns.pairplot(df_auto)

# %% [markdown]
# * From the first column from above pairplot, we see that mpg has strong relationships with cylinder, displacement, weights, acceleration and year as well. We need to deep dive and see if they have high correlations and statistical significant impact as well. (Strong t-stats if regressed across these variables).
#
#
# * High cylinder vehicles (Heavy duty, large moving, transport vehicles tend to have lower acceleration and mpg).

# %% [markdown]
# ## Question 10).
#
# ### 10 (a).
#
# How many rows are in this data set? How many columns? What
# do the rows and columns represent?

# %%
from sklearn.datasets import load_boston
bos = load_boston()
X, y = load_boston(return_X_y=True)
df_bos = pd.DataFrame(X, columns=bos.feature_names)
df_bos['y'] = y

# %%
df_bos.shape, y.shape
# Out:
# ((506, 14), (506,))

# %% [markdown]
# * There are 506 rows, 13 features & one label column.

# %%
df_bos.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT     y
# 0     15.3  396.9   4.98  24.0
# 1     17.8  396.9   9.14  21.6

# %% [markdown]
# ### 10 (b).
#
# Make some pairwise scatterplots of the predictors (columns) in
# this data set. Describe your findings.

# %%
sns.pairplot(df_bos, y_vars='y', x_vars=df_bos.columns[:7])

# %%
sns.pairplot(df_bos, y_vars='y', x_vars=df_bos.columns[7:])

# %% [markdown]
# * NOX, RM, AGE, TAX and LSTAT are obvious visual trends to predict y.

# %% [markdown]
# ### 10 (c).
#
# Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship.

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df_bos.corr(), annot=True)

# %% [markdown]
# * INDUS, LSTAT, RAD are positively correlated. DIS & B are negatively correlated.

# %% [markdown]
# ### 10 (d).
#
# Do any of the suburbs of Boston appear to have particularly
# high crime rates? Tax rates? Pupil-teacher ratios? Comment on
# the range of each predictor.

# %%
sns.distplot(df_bos.CRIM)

# %%
df_bos.CRIM.describe()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: CRIM, dtype: float64

# %% [markdown]
# * Yes, looking at the displot & 75 % percentile above, we can say there are a few suburbs with high Crime rate. As expected, it is highly skewed.

# %%
sns.distplot(df_bos.TAX)

# %%
df_bos.TAX.describe()
# Out:
# count    506.000000
# mean     408.237154
# std      168.537116
# min      187.000000
# 25%      279.000000
# 50%      330.000000
# 75%      666.000000
# max      711.000000
# Name: TAX, dtype: float64

# %% [markdown]
# * TAX is not as skewed as CRIM. However, there is slight skew with mean much above the 50th percentile. The distribution is also bi-modal (visually), and can broadly classify each suburb into either high or low rate (with 1/3rd in high and 2/3rds in low).

# %%
sns.distplot(df_bos.PTRATIO)

# %%
df_bos.PTRATIO.describe()
# Out:
# count    506.000000
# mean      18.455534
# std        2.164946
# min       12.600000
# 25%       17.400000
# 50%       19.050000
# 75%       20.200000
# max       22.000000
# Name: PTRATIO, dtype: float64

# %% [markdown]
# * FRom the above distplot and summary, we see that most of suburbs have high number of pupils per teacher (which is a general case).

# %%
df_bos[df_bos.columns[:-1]].describe().T[['min', 'max']]
# Out:
#                min       max
# CRIM       0.00632   88.9762
# ZN         0.00000  100.0000
# INDUS      0.46000   27.7400
# CHAS       0.00000    1.0000
# NOX        0.38500    0.8710
# RM         3.56100    8.7800
# AGE        2.90000  100.0000
# DIS        1.12960   12.1265
# RAD        1.00000   24.0000
# TAX      187.00000  711.0000
# PTRATIO   12.60000   22.0000
# B          0.32000  396.9000
# LSTAT      1.73000   37.9700

# %% [markdown]
# ### 10 (e).
# How many of the suburbs in this data set bound the Charles
# river?

# %%
df_bos.CHAS.sum(), df_bos.CHAS.sum()/len(df_bos)
# Out:
# (35.0, 0.0691699604743083)

# %% [markdown]
# * 35 suburbs or approx. 7 % of suburbs falls set bound Charles river.

# %% [markdown]
# ### 10 (f).
# What is the median pupil-teacher ratio among the towns in this
# data set?

# %%
df_bos.PTRATIO.median()
# Out:
# 19.05

# %% [markdown]
# ### 10 (g).
# Which suburb of Boston has lowest median value of owneroccupied homes? What are the values of the other predictors
# for that suburb, and how do those values compare to the overall
# ranges for those predictors? Comment on your findings.

# %%
df_bos[df_bos.AGE == df_bos.AGE.min()]
# Out:
#        CRIM   ZN  INDUS  CHAS    NOX    RM  AGE     DIS  RAD    TAX  PTRATIO  \
# 41  0.12744  0.0   6.91   0.0  0.448  6.77  2.9  5.7209  3.0  233.0     17.9
#
#          B  LSTAT     y
# 41  385.41   4.84  26.6

# %%
df_bos[df_bos.columns[:-1]].describe().T[['min', 'max']].T
# Out:
#          CRIM     ZN  INDUS  CHAS    NOX     RM    AGE      DIS   RAD    TAX  \
# min   0.00632    0.0   0.46   0.0  0.385  3.561    2.9   1.1296   1.0  187.0
# max  88.97620  100.0  27.74   1.0  0.871  8.780  100.0  12.1265  24.0  711.0
#
#      PTRATIO       B  LSTAT
# min     12.6    0.32   1.73
# max     22.0  396.90  37.97

# %% [markdown]
# * ZN is at minimum at suburb with least owner occupied homes. It also has a slight high pupil teacher ratio and high B column.

# %% [markdown]
# ### 10 (h).
# In this data set, how many of the suburbs average more than
# seven rooms per dwelling? More than eight rooms per dwelling?
# Comment on the suburbs that average more than eight rooms
# per dwelling.

# %%
df_bos[df_bos.RM > 7].shape[0], df_bos[df_bos.RM > 8].shape[0]
# Out:
# (64, 13)

# %%
df_bos[df_bos.RM > 8].describe().T[['mean']]
# Out:
#                mean
# CRIM       0.718795
# ZN        13.615385
# INDUS      7.078462
# CHAS       0.153846
# NOX        0.539238
# RM         8.348538
# AGE       71.538462
# DIS        3.430192
# RAD        7.461538
# TAX      325.076923
# PTRATIO   16.361538
# B        385.210769
# LSTAT      4.310000
# y         44.200000

# %%
df_bos.describe().T[['mean']]
# Out:
#                mean
# CRIM       3.613524
# ZN        11.363636
# INDUS     11.136779
# CHAS       0.069170
# NOX        0.554695
# RM         6.284634
# AGE       68.574901
# DIS        3.795043
# RAD        9.549407
# TAX      408.237154
# PTRATIO   18.455534
# B        356.674032
# LSTAT     12.653063
# y         22.532806

# %% [markdown]
# * When compared to overall dataset, there is lesser crime, low LSTAT, lower TAX, higher CHAS for subset with > 8 rooms per dwelling.
